# %%
import os
import pandas as pd
import networkx as nx
from tqdm.notebook import tqdm

# %%
ROOT = './gml_connected_graphs'  # './gml_graphs'
EMPTY_FAMILY = ''

# %%
paths = []
for fname in sorted(os.listdir(ROOT)):
    path = f'./gml_connected_graphs/{fname}'
    if fname.endswith('.gml'):
        paths.append((EMPTY_FAMILY, path))
    elif os.path.isdir(path):  # this is a family
        family = fname
        paths_family = [(family, f'{path}/{fname}') for fname in sorted(os.listdir(path)) if fname.endswith('.gml')]
        paths.extend(paths_family)
paths
# Out:
# [('', './gml_connected_graphs/as.gml'),
#  ('', './gml_connected_graphs/citeseer.gml'),
#  ('cora', './gml_connected_graphs/cora/cora.gml'),
#  ('cora', './gml_connected_graphs/cora/cora_full.gml'),
#  ('cora_subset',
#   './gml_connected_graphs/cora_subset/Artificial_Intelligence.gml'),
#  ('cora_subset',
#   './gml_connected_graphs/cora_subset/Artificial_Intelligence__Machine_Learning.gml'),
#  ('cora_subset',
#   './gml_connected_graphs/cora_subset/Data_Structures__Algorithms_and_Theory.gml'),
#  ('cora_subset', './gml_connected_graphs/cora_subset/Databases.gml'),
#  ('cora_subset',
#   './gml_connected_graphs/cora_subset/Encryption_and_Compression.gml'),
#  ('cora_subset',
#   './gml_connected_graphs/cora_subset/Hardware_and_Architecture.gml'),
#  ('cora_subset',
#   './gml_connected_graphs/cora_subset/Human_Computer_Interaction.gml'),
#  ('cora_subset',
#   './gml_connected_graphs/cora_subset/Information_Retrieval.gml'),
#  ('cora_subset', './gml_connected_graphs/cora_subset/Networking.gml'),
#  ('cora_subset', './gml_connected_graphs/cora_subset/Operating_Systems.gml'),
#  ('cora_subset', './gml_connected_graphs/cora_subset/Programming.gml'),
#  ('', './gml_connected_graphs/dolphins.gml'),
#  ('', './gml_connected_graphs/eu-core.gml'),
#  ('', './gml_connected_graphs/eurosis.gml'),
#  ('', './gml_connected_graphs/football.gml'),
#  ('', './gml_connected_graphs/karate.gml'),
#  ('newsgroup', './gml_connected_graphs/newsgroup/news_2cl_1.gml'),
#  ('newsgroup', './gml_connected_graphs/newsgroup/news_2cl_2.gml'),
#  ('newsgroup', './gml_connected_graphs/newsgroup/news_2cl_3.gml'),
#  ('newsgroup', './gml_connected_graphs/newsgroup/news_3cl_1.gml'),
#  ('newsgroup', './gml_connected_graphs/newsgroup/news_3cl_2.gml'),
#  ('newsgroup', './gml_connected_graphs/newsgroup/news_3cl_3.gml'),
#  ('newsgroup', './gml_connected_graphs/newsgroup/news_5cl_1.gml'),
#  ('newsgroup', './gml_connected_graphs/newsgroup/news_5cl_2.gml'),
#  ('newsgroup', './gml_connected_graphs/newsgroup/news_5cl_3.gml'),
#  ('newsgroup_0.1', './gml_connected_graphs/newsgroup_0.1/news_2cl1_0.1.gml'),
#  ('newsgroup_0.1', './gml_connected_graphs/newsgroup_0.1/news_2cl2_0.1.gml'),
#  ('newsgroup_0.1', './gml_connected_graphs/newsgroup_0.1/news_2cl3_0.1.gml'),
#  ('newsgroup_0.1', './gml_connected_graphs/newsgroup_0.1/news_3cl1_0.1.gml'),
#  ('newsgroup_0.1', './gml_connected_graphs/newsgroup_0.1/news_3cl2_0.1.gml'),
#  ('newsgroup_0.1', './gml_connected_graphs/newsgroup_0.1/news_3cl3_0.1.gml'),
#  ('newsgroup_0.1', './gml_connected_graphs/newsgroup_0.1/news_5cl1_0.1.gml'),
#  ('newsgroup_0.1', './gml_connected_graphs/newsgroup_0.1/news_5cl2_0.1.gml'),
#  ('newsgroup_0.1', './gml_connected_graphs/newsgroup_0.1/news_5cl3_0.1.gml'),
#  ('', './gml_connected_graphs/polblogs.gml'),
#  ('', './gml_connected_graphs/polbooks.gml'),
#  ('sp_school', './gml_connected_graphs/sp_school/sp_school_day_1.gml'),
#  ('sp_school', './gml_connected_graphs/sp_school/sp_school_day_2.gml')]

# %% [raw]
# for folder, path in paths:
#     new_basepath = f'gml_connected_graphs/{folder}' if folder != '' else f'gml_connected_graphs'
#     new_filename = path.split('/')[-1]
#     print(new_filename)
#     try:
#         os.mkdir(new_basepath)
#     except:
#         pass
#     G = nx.read_gml(path)
#     if nx.is_directed(G):
#         G = G.to_undirected()
#     Gc = max([G.subgraph(c) for c in nx.connected_components(G)], key=len)
#     nx.write_gml(Gc, f'{new_basepath}/{new_filename}')

# %%
stat = []
for family, path in tqdm(paths):
    G = nx.read_gml(path)
    stat.append({
        'family': family,
        'name': os.path.basename(path)[:-4],
        'n_nodes': G.number_of_nodes(),
        'n_edges': G.number_of_edges(),
        'n_classes': len(set(nx.get_node_attributes(G, 'gt').values()))
    })
# Out:
# HBox(children=(FloatProgress(value=0.0, max=42.0), HTML(value='')))

# %%
df = pd.DataFrame(stat)
df
# Out:
#            family                                       name  n_nodes  \
# 0                                                         as    23748
# 1                                                   citeseer     2120
# 2            cora                                       cora     2485
# 3            cora                                  cora_full    23166
# 4     cora_subset                    Artificial_Intelligence     4633
# 5     cora_subset  Artificial_Intelligence__Machine_Learning     3323
# 6     cora_subset     Data_Structures__Algorithms_and_Theory     1777
# 7     cora_subset                                  Databases     1006
# 8     cora_subset                 Encryption_and_Compression      592
# 9     cora_subset                  Hardware_and_Architecture      626
# 10    cora_subset                 Human_Computer_Interaction     1053
# 11    cora_subset                      Information_Retrieval      418
# 12    cora_subset                                 Networking     1167
# 13    cora_subset                          Operating_Systems     2068
# 14    cora_subset                                Programming     3007
# 15                                                  dolphins       62
# 16                                                   eu-core      986
# 17                                                   eurosis     1272
# 18                                                  football      115
# 19                                                    karate       34
# 20      newsgroup                                 news_2cl_1      400
# 21      newsgroup                                 news_2cl_2      398
# 22      newsgroup                                 news_2cl_3      399
# 23      newsgroup                                 news_3cl_1      600
# 24      newsgroup                                 news_3cl_2      598
# 25      newsgroup                                 news_3cl_3      595
# 26      newsgroup                                 news_5cl_1      998
# 27      newsgroup                                 news_5cl_2      999
# 28      newsgroup                                 news_5cl_3      997
# 29  newsgroup_0.1                              news_2cl1_0.1      398
# 30  newsgroup_0.1                              news_2cl2_0.1      398
# 31  newsgroup_0.1                              news_2cl3_0.1      398
# 32  newsgroup_0.1                              news_3cl1_0.1      599
# 33  newsgroup_0.1                              news_3cl2_0.1      598
# 34  newsgroup_0.1                              news_3cl3_0.1      595
# 35  newsgroup_0.1                              news_5cl1_0.1      998
# 36  newsgroup_0.1                              news_5cl2_0.1      999
# 37  newsgroup_0.1                              news_5cl3_0.1      997
# 38                                                  polblogs     1222
# 39                                                  polbooks      105
# 40      sp_school                            sp_school_day_1      236
# 41      sp_school                            sp_school_day_2      238
#
#     n_edges  n_classes
# 0     58414        176
# 1      3731          6
# 2      5069          7
# 3     89157         70
# 4     12958         11
# 5     10603          7
# 6      4323          9
# 7      3155          7
# 8      1579          3
# 9      1486          7
# 10     2350          5
# 11     1110          4
# 12     3904          4
# 13     8654          4
# 14    10479          9
# 15      159          2
# 16    16687         42
# 17     6454         13
# 18      613         12
# 19       78          2
# 20    33854          2
# 21    21480          2
# 22    36527          2
# 23    70591          3
# 24    68201          3
# 25    64169          3
# 26   176962          5
# 27   164452          5
# 28   155618          5
# 29     2634          2
# 30     2455          2
# 31     3347          2
# 32     5129          3
# 33     5041          3
# 34     4557          3
# 35    11525          5
# 36    10194          5
# 37     9791          5
# 38    16717          2
# 39      441          3
# 40     5899         11
# 41     5539         11

# %%
for idx, cols in enumerate(df.to_numpy().tolist()):
    print(' | '.join([str(x) for x in [idx] + cols]))
# Out:
# 0 |  | as | 23748 | 58414 | 176
# 1 |  | citeseer | 2120 | 3731 | 6
# 2 | cora | cora | 2485 | 5069 | 7
# 3 | cora | cora_full | 23166 | 89157 | 70
# 4 | cora_subset | Artificial_Intelligence | 4633 | 12958 | 11
# 5 | cora_subset | Artificial_Intelligence__Machine_Learning | 3323 | 10603 | 7
# 6 | cora_subset | Data_Structures__Algorithms_and_Theory | 1777 | 4323 | 9
# 7 | cora_subset | Databases | 1006 | 3155 | 7
# 8 | cora_subset | Encryption_and_Compression | 592 | 1579 | 3
# 9 | cora_subset | Hardware_and_Architecture | 626 | 1486 | 7
# 10 | cora_subset | Human_Computer_Interaction | 1053 | 2350 | 5
# 11 | cora_subset | Information_Retrieval | 418 | 1110 | 4
# 12 | cora_subset | Networking | 1167 | 3904 | 4
# 13 | cora_subset | Operating_Systems | 2068 | 8654 | 4
# 14 | cora_subset | Programming | 3007 | 10479 | 9
# 15 |  | dolphins | 62 | 159 | 2
# 16 |  | eu-core | 986 | 16687 | 42
# 17 |  | eurosis | 1272 | 6454 | 13
# 18 |  | football | 115 | 613 | 12
# 19 |  | karate | 34 | 78 | 2
# 20 | newsgroup | news_2cl_1 | 400 | 33854 | 2
# 21 | newsgroup | news_2cl_2 | 398 | 21480 | 2
# 22 | newsgroup | news_2cl_3 | 399 | 36527 | 2
# 23 | newsgroup | news_3cl_1 | 600 | 70591 | 3
# 24 | newsgroup | news_3cl_2 | 598 | 68201 | 3
# 25 | newsgroup | news_3cl_3 | 595 | 64169 | 3
# 26 | newsgroup | news_5cl_1 | 998 | 176962 | 5
# 27 | newsgroup | news_5cl_2 | 999 | 164452 | 5
# 28 | newsgroup | news_5cl_3 | 997 | 155618 | 5
# 29 | newsgroup_0.1 | news_2cl1_0.1 | 398 | 2634 | 2
# 30 | newsgroup_0.1 | news_2cl2_0.1 | 398 | 2455 | 2
# 31 | newsgroup_0.1 | news_2cl3_0.1 | 398 | 3347 | 2
# 32 | newsgroup_0.1 | news_3cl1_0.1 | 599 | 5129 | 3
# 33 | newsgroup_0.1 | news_3cl2_0.1 | 598 | 5041 | 3
# 34 | newsgroup_0.1 | news_3cl3_0.1 | 595 | 4557 | 3
# 35 | newsgroup_0.1 | news_5cl1_0.1 | 998 | 11525 | 5
# 36 | newsgroup_0.1 | news_5cl2_0.1 | 999 | 10194 | 5
# 37 | newsgroup_0.1 | news_5cl3_0.1 | 997 | 9791 | 5
# 38 |  | polblogs | 1222 | 16717 | 2
# 39 |  | polbooks | 105 | 441 | 3
# 40 | sp_school | sp_school_day_1 | 236 | 5899 | 11
# 41 | sp_school | sp_school_day_2 | 238 | 5539 | 11
